# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sinasc = pd.read_csv('https://raw.githubusercontent.com/vinisavordelli/exercicios_ebac/main/Ci%C3%AAncia%20de%20Dados/Exercicio_5/SINASC_RO_2019.csv', sep=',')
# Out:
# 53

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
## sinasc['faixa_etaria'] = pd.cut(sinasc['IDADEMAE'], bins=[0, 18, 25, 30, 35, 40, 45, 150], labels=['<18', '18-25', '25-30', '30-35', '35-40', '40-45', '45+'])

sns.boxplot(y='IDADEMAE', data=sinasc, color='#8af2e1')
# Out:
# <Axes: ylabel='IDADEMAE'>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(y='PESO', data=sinasc, color='#f59871')
# Out:
# <Axes: ylabel='PESO'>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.histplot(x='IDADEMAE', data=sinasc, color='#ea9cf0', bins=43, element='step', kde=True, alpha=0.4)
# Out:
# <Axes: xlabel='IDADEMAE', ylabel='Count'>

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.histplot(x='PESO', data=sinasc, color='#3256a8', bins=25, element='step', alpha=0.4)
# Out:
# <Axes: xlabel='PESO', ylabel='Count'>
